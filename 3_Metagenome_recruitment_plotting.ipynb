# %% [markdown]
# ### Exploring the output from CoverM
#
# We've used all SAGs on AG-910 as the input genomes, and the metagenomes from BATs surface samples as inputs for coverM.  Let's see what the results look like.
#
# First we'll import a couple of libraries:

# %%
import pandas as pd    # for reading and munging data frames
import matplotlib.pyplot as plt # a python plotting library
import seaborn as sns    # a python library for creating simple, nice looking plots with matplotlib

from matplotlib.dates import DateFormatter


from collections import Counter # an easy way to count elements in a list

# %% [markdown]
# Now we will load a couple different data tables, and will need to clean them up a bit so that they are ready to play with.

# %%
metagenome_metadata = "/mnt/storage/data/metagenomes/bats_metagenomes_of_interest.csv"

sag_metadata = "/mnt/storage/data/AG-910_assembly_stats.csv"

#you can upload the datatable you produced; I have copied the table I produced in the folder below to make sure that everyone has access
recruitment_table = "/mnt/storage/data/metagenomes/AG_910_BATS_coverm_relabundance"

# %%
# load the recruitment table and call it 'rdf' for 'recruitment dataframe'
rdf = pd.read_csv(recruitment_table, sep = "\t")
rdf.head()
# Out:
#                      Genome  SRR5720233_1.fastq.gz Relative Abundance (%)  \
# 0                  unmapped                                      96.03955
# 1  final_contigs_AG-910-A01                                       0.00000
# 2  final_contigs_AG-910-A02                                       0.00000
# 3  final_contigs_AG-910-A03                                       0.00000
# 4  final_contigs_AG-910-A04                                       0.00000
#
#    SRR5720235_1.fastq.gz Relative Abundance (%)  \
# 0                                      74.62650
# 1                                       0.00000
# 2                                       0.11403
# 3                                       0.00000
# 4                                       0.00000
#
#    SRR5720238_1.fastq.gz Relative Abundance (%)  \
# 0                                       97.4597
# 1                                        0.0000
# 2                                        0.0000
# 3                                        0.0000
# 4                                        0.0000
#
#    SRR5720251_1.fastq.gz Relative Abundance (%)  \
# 0                                     86.320450
# 1                                      0.000000
# 2                                      0.047097
# 3                                      0.000000
# 4                                      0.072789
#
#    SRR5720256_1.fastq.gz Relative Abundance (%)  \
# 0                                     96.239944
# 1                                      0.000000
# 2                                      0.000000
# 3                                      0.000000
# 4                                      0.029948
#
#    SRR5720257_1.fastq.gz Relative Abundance (%)  \
# 0                                     76.807350
# 1                                      0.000000
# 2                                      0.077622
# 3                                      0.000000
# 4                                      0.085005
#
#    SRR5720260_1.fastq.gz Relative Abundance (%)  \
# 0                                     74.888400
# 1                                      0.000000
# 2                                      0.133476
# 3                                      0.000000
# 4                                      0.035151
#
#    SRR5720262_1.fastq.gz Relative Abundance (%)  \
# 0                                     89.599650
# 1                                      0.000000
# 2                                      0.041016
# 3                                      0.000000
# 4                                      0.066377
#
#    SRR5720276_1.fastq.gz Relative Abundance (%)  ...  \
# 0                                     86.710205  ...
# 1                                      0.000000  ...
# 2                                      0.000000  ...
# 3                                      0.000000  ...
# 4                                      0.087819  ...
#
#    SRR5720286_1.fastq.gz Relative Abundance (%)  \
# 0                                     66.948800
# 1                                      0.000000
# 2                                      0.154068
# 3                                      0.000000
# 4                                      0.051315
#
#    SRR5720307_1.fastq.gz Relative Abundance (%)  \
# 0                                     84.922850
# 1                                      0.000000
# 2                                      0.032314
# 3                                      0.000000
# 4                                      0.077863
#
#    SRR5720321_1.fastq.gz Relative Abundance (%)  \
# 0                                     79.472946
# 1                                      0.000000
# 2                                      0.116073
# 3                                      0.000000
# 4                                      0.049893
#
#    SRR5720322_1.fastq.gz Relative Abundance (%)  \
# 0                                     93.079550
# 1                                      0.000000
# 2                                      0.000000
# 3                                      0.000000
# 4                                      0.043773
#
#    SRR5720327_1.fastq.gz Relative Abundance (%)  \
# 0                                     82.363000
# 1                                      0.000000
# 2                                      0.120580
# 3                                      0.000000
# 4                                      0.071633
#
#    SRR5720332_1.fastq.gz Relative Abundance (%)  \
# 0                                     87.753555
# 1                                      0.000000
# 2                                      0.031029
# 3                                      0.000000
# 4                                      0.058430
#
#    SRR5720337_1.fastq.gz Relative Abundance (%)  \
# 0                                      97.47311
# 1                                       0.00000
# 2                                       0.00000
# 3                                       0.00000
# 4                                       0.00000
#
#    SRR5720338_1.fastq.gz Relative Abundance (%)  \
# 0                                     97.938194
# 1                                      0.000000
# 2                                      0.000000
# 3                                      0.000000
# 4                                      0.000000
#
#    SRR5720342_1.fastq.gz Relative Abundance (%)  \
# 0                                     88.918045
# 1                                      0.000000
# 2                                      0.035016
# 3                                      0.000000
# 4                                      0.075826
#
#    SRR6507279_1.fastq.gz Relative Abundance (%)
# 0                                     71.081750
# 1                                      0.000000
# 2                                      0.117303
# 3                                      0.000000
# 4                                      0.289785
#
# [5 rows x 22 columns]

# %% [markdown]
# This is a data matrix with relative metagenomic abundance for columns, and SAGs for rows.  You'll notice there's also a row for unmapped reads.
#
# The first thing I'm going to do with this table is clean up the column and row names so that they're easier to work with and match to the metadata tables.
#
# For the 'genomes column',  I will remove the 'final_contigs' prefix.

# %%
rdf['Genome'] = [i.replace('final_contigs_','') for i in rdf['Genome']]
rdf.head()
# Out:
#        Genome  SRR5720233_1.fastq.gz Relative Abundance (%)  \
# 0    unmapped                                      96.03955
# 1  AG-910-A01                                       0.00000
# 2  AG-910-A02                                       0.00000
# 3  AG-910-A03                                       0.00000
# 4  AG-910-A04                                       0.00000
#
#    SRR5720235_1.fastq.gz Relative Abundance (%)  \
# 0                                      74.62650
# 1                                       0.00000
# 2                                       0.11403
# 3                                       0.00000
# 4                                       0.00000
#
#    SRR5720238_1.fastq.gz Relative Abundance (%)  \
# 0                                       97.4597
# 1                                        0.0000
# 2                                        0.0000
# 3                                        0.0000
# 4                                        0.0000
#
#    SRR5720251_1.fastq.gz Relative Abundance (%)  \
# 0                                     86.320450
# 1                                      0.000000
# 2                                      0.047097
# 3                                      0.000000
# 4                                      0.072789
#
#    SRR5720256_1.fastq.gz Relative Abundance (%)  \
# 0                                     96.239944
# 1                                      0.000000
# 2                                      0.000000
# 3                                      0.000000
# 4                                      0.029948
#
#    SRR5720257_1.fastq.gz Relative Abundance (%)  \
# 0                                     76.807350
# 1                                      0.000000
# 2                                      0.077622
# 3                                      0.000000
# 4                                      0.085005
#
#    SRR5720260_1.fastq.gz Relative Abundance (%)  \
# 0                                     74.888400
# 1                                      0.000000
# 2                                      0.133476
# 3                                      0.000000
# 4                                      0.035151
#
#    SRR5720262_1.fastq.gz Relative Abundance (%)  \
# 0                                     89.599650
# 1                                      0.000000
# 2                                      0.041016
# 3                                      0.000000
# 4                                      0.066377
#
#    SRR5720276_1.fastq.gz Relative Abundance (%)  ...  \
# 0                                     86.710205  ...
# 1                                      0.000000  ...
# 2                                      0.000000  ...
# 3                                      0.000000  ...
# 4                                      0.087819  ...
#
#    SRR5720286_1.fastq.gz Relative Abundance (%)  \
# 0                                     66.948800
# 1                                      0.000000
# 2                                      0.154068
# 3                                      0.000000
# 4                                      0.051315
#
#    SRR5720307_1.fastq.gz Relative Abundance (%)  \
# 0                                     84.922850
# 1                                      0.000000
# 2                                      0.032314
# 3                                      0.000000
# 4                                      0.077863
#
#    SRR5720321_1.fastq.gz Relative Abundance (%)  \
# 0                                     79.472946
# 1                                      0.000000
# 2                                      0.116073
# 3                                      0.000000
# 4                                      0.049893
#
#    SRR5720322_1.fastq.gz Relative Abundance (%)  \
# 0                                     93.079550
# 1                                      0.000000
# 2                                      0.000000
# 3                                      0.000000
# 4                                      0.043773
#
#    SRR5720327_1.fastq.gz Relative Abundance (%)  \
# 0                                     82.363000
# 1                                      0.000000
# 2                                      0.120580
# 3                                      0.000000
# 4                                      0.071633
#
#    SRR5720332_1.fastq.gz Relative Abundance (%)  \
# 0                                     87.753555
# 1                                      0.000000
# 2                                      0.031029
# 3                                      0.000000
# 4                                      0.058430
#
#    SRR5720337_1.fastq.gz Relative Abundance (%)  \
# 0                                      97.47311
# 1                                       0.00000
# 2                                       0.00000
# 3                                       0.00000
# 4                                       0.00000
#
#    SRR5720338_1.fastq.gz Relative Abundance (%)  \
# 0                                     97.938194
# 1                                      0.000000
# 2                                      0.000000
# 3                                      0.000000
# 4                                      0.000000
#
#    SRR5720342_1.fastq.gz Relative Abundance (%)  \
# 0                                     88.918045
# 1                                      0.000000
# 2                                      0.035016
# 3                                      0.000000
# 4                                      0.075826
#
#    SRR6507279_1.fastq.gz Relative Abundance (%)
# 0                                     71.081750
# 1                                      0.000000
# 2                                      0.117303
# 3                                      0.000000
# 4                                      0.289785
#
# [5 rows x 22 columns]

# %%
# checking column names

rdf.columns
# Out:
# Index(['Genome', 'SRR5720233_1.fastq.gz Relative Abundance (%)',
#        'SRR5720235_1.fastq.gz Relative Abundance (%)',
#        'SRR5720238_1.fastq.gz Relative Abundance (%)',
#        'SRR5720251_1.fastq.gz Relative Abundance (%)',
#        'SRR5720256_1.fastq.gz Relative Abundance (%)',
#        'SRR5720257_1.fastq.gz Relative Abundance (%)',
#        'SRR5720260_1.fastq.gz Relative Abundance (%)',
#        'SRR5720262_1.fastq.gz Relative Abundance (%)',
#        'SRR5720276_1.fastq.gz Relative Abundance (%)',
#        'SRR5720278_1.fastq.gz Relative Abundance (%)',
#        'SRR5720283_1.fastq.gz Relative Abundance (%)',
#        'SRR5720286_1.fastq.gz Relative Abundance (%)',
#        'SRR5720307_1.fastq.gz Relative Abundance (%)',
#        'SRR5720321_1.fastq.gz Relative Abundance (%)',
#        'SRR5720322_1.fastq.gz Relative Abundance (%)',
#        'SRR5720327_1.fastq.gz Relative Abundance (%)',
#        'SRR5720332_1.fastq.gz Relative Abundance (%)',
#        'SRR5720337_1.fastq.gz Relative Abundance (%)',
#        'SRR5720338_1.fastq.gz Relative Abundance (%)',
#        'SRR5720342_1.fastq.gz Relative Abundance (%)',
#        'SRR6507279_1.fastq.gz Relative Abundance (%)'],
#       dtype='object')

# %% [markdown]
# For the column names I will remove everything after the _ (keep only the SRR identifier)

# %%
# clean up column names

new_colnames = [i if '_' not in i else i.split("_")[0] for i in rdf.columns]
new_colnames
# Out:
# ['Genome',
#  'SRR5720233',
#  'SRR5720235',
#  'SRR5720238',
#  'SRR5720251',
#  'SRR5720256',
#  'SRR5720257',
#  'SRR5720260',
#  'SRR5720262',
#  'SRR5720276',
#  'SRR5720278',
#  'SRR5720283',
#  'SRR5720286',
#  'SRR5720307',
#  'SRR5720321',
#  'SRR5720322',
#  'SRR5720327',
#  'SRR5720332',
#  'SRR5720337',
#  'SRR5720338',
#  'SRR5720342',
#  'SRR6507279']

# %%
rdf.columns = new_colnames
rdf.head()
# Out:
#        Genome  SRR5720233  SRR5720235  SRR5720238  SRR5720251  SRR5720256  \
# 0    unmapped    96.03955    74.62650     97.4597   86.320450   96.239944
# 1  AG-910-A01     0.00000     0.00000      0.0000    0.000000    0.000000
# 2  AG-910-A02     0.00000     0.11403      0.0000    0.047097    0.000000
# 3  AG-910-A03     0.00000     0.00000      0.0000    0.000000    0.000000
# 4  AG-910-A04     0.00000     0.00000      0.0000    0.072789    0.029948
#
#    SRR5720257  SRR5720260  SRR5720262  SRR5720276  ...  SRR5720286  \
# 0   76.807350   74.888400   89.599650   86.710205  ...   66.948800
# 1    0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 2    0.077622    0.133476    0.041016    0.000000  ...    0.154068
# 3    0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 4    0.085005    0.035151    0.066377    0.087819  ...    0.051315
#
#    SRR5720307  SRR5720321  SRR5720322  SRR5720327  SRR5720332  SRR5720337  \
# 0   84.922850   79.472946   93.079550   82.363000   87.753555    97.47311
# 1    0.000000    0.000000    0.000000    0.000000    0.000000     0.00000
# 2    0.032314    0.116073    0.000000    0.120580    0.031029     0.00000
# 3    0.000000    0.000000    0.000000    0.000000    0.000000     0.00000
# 4    0.077863    0.049893    0.043773    0.071633    0.058430     0.00000
#
#    SRR5720338  SRR5720342  SRR6507279
# 0   97.938194   88.918045   71.081750
# 1    0.000000    0.000000    0.000000
# 2    0.000000    0.035016    0.117303
# 3    0.000000    0.000000    0.000000
# 4    0.000000    0.075826    0.289785
#
# [5 rows x 22 columns]

# %% [markdown]
# Finally, I want to melt the table (tranform the "wide" format to "long" format, i.e. that row is a single observation).  This will be help for data matching, merging and plotting.

# %%
rdf_melt = rdf.melt(id_vars = 'Genome', var_name = 'metagenome',value_name = 'perc_rel_abund')

#assign a new table rdf_long that has the values of rdf_melt
rdf_long = rdf_melt
rdf_long.head()
# Out:
#        Genome  metagenome  perc_rel_abund
# 0    unmapped  SRR5720233        96.03955
# 1  AG-910-A01  SRR5720233         0.00000
# 2  AG-910-A02  SRR5720233         0.00000
# 3  AG-910-A03  SRR5720233         0.00000
# 4  AG-910-A04  SRR5720233         0.00000

# %% [markdown]
# Now let's load the metagenome metadata:

# %%
mg_metadata = pd.read_csv(metagenome_metadata)
mg_metadata = mg_metadata[mg_metadata['downloaded'] == 'yes'].copy()

#append 'mg' to column names for table merging:

mg_metadata.columns = ['mg_' + i for i in mg_metadata.columns]

# %%
print("metadata columns:\n", mg_metadata.columns)
# Out:
# metadata columns:
#  Index(['mg_Run', 'mg_Collection_date', 'mg_cruise_id', 'mg_BioSample',
#        'mg_Depth', 'mg_downloaded'],
#       dtype='object')

# %%
mg_metadata
# Out:
#         mg_Run mg_Collection_date mg_cruise_id  mg_BioSample mg_Depth  \
# 0   SRR5720233         2003-02-21      BATS173  SAMN07137079       1m
# 1   SRR5720238         2003-03-22      BATS174  SAMN07137082       1m
# 2   SRR5720327         2003-04-22      BATS175  SAMN07137064      10m
# 3   SRR5720283         2003-05-20      BATS176  SAMN07137103       1m
# 4   SRR5720235         2003-07-15      BATS178  SAMN07137085      10m
# 5   SRR5720286         2003-08-12      BATS179  SAMN07137088      10m
# 6   SRR5720332         2003-10-07      BATS181  SAMN07137067       1m
# 7   SRR5720276         2003-11-04      BATS182  SAMN07137106       1m
# 8   SRR5720262         2003-12-02      BATS183  SAMN07137109       1m
# 9   SRR5720338         2004-01-27      BATS184  SAMN07137070       1m
# 10  SRR5720322         2004-02-24      BATS185  SAMN07137121       1m
# 11  SRR5720337         2004-03-23      BATS186  SAMN07137073       1m
# 12  SRR5720256         2004-04-21      BATS187  SAMN07137091       1m
# 13  SRR5720257         2004-05-18      BATS188  SAMN07137112      10m
# 14  SRR5720260         2004-06-15      BATS189  SAMN07137115      10m
# 15  SRR5720321         2004-08-17      BATS191  SAMN07137118       1m
# 16  SRR5720251         2004-09-14      BATS192  SAMN07137094       1m
# 17  SRR5720307         2004-10-13      BATS193  SAMN07137097       1m
# 18  SRR5720278         2004-11-12      BATS194  SAMN07137100       1m
# 19  SRR5720342         2004-12-08      BATS195  SAMN07137076       1m
# 20  SRR6507279         2009-07-14      BATS248  SAMN08390924      10m
#
#    mg_downloaded
# 0            yes
# 1            yes
# 2            yes
# 3            yes
# 4            yes
# 5            yes
# 6            yes
# 7            yes
# 8            yes
# 9            yes
# 10           yes
# 11           yes
# 12           yes
# 13           yes
# 14           yes
# 15           yes
# 16           yes
# 17           yes
# 18           yes
# 19           yes
# 20           yes

# %%
bdf = rdf_long.merge(mg_metadata, left_on = 'metagenome', right_on = 'mg_Run', how = 'left')

# check to see that there are the same number of rows in the old and new dataframe
print(len(rdf_long), len(bdf))
# Out:
# 5523 5523

# %%
bdf
# Out:
#           Genome  metagenome  perc_rel_abund      mg_Run mg_Collection_date  \
# 0       unmapped  SRR5720233       96.039550  SRR5720233         2003-02-21
# 1     AG-910-A01  SRR5720233        0.000000  SRR5720233         2003-02-21
# 2     AG-910-A02  SRR5720233        0.000000  SRR5720233         2003-02-21
# 3     AG-910-A03  SRR5720233        0.000000  SRR5720233         2003-02-21
# 4     AG-910-A04  SRR5720233        0.000000  SRR5720233         2003-02-21
# ...          ...         ...             ...         ...                ...
# 5518  AG-910-P09  SRR6507279        0.000000  SRR6507279         2009-07-14
# 5519  AG-910-P13  SRR6507279        0.089771  SRR6507279         2009-07-14
# 5520  AG-910-P17  SRR6507279        0.197070  SRR6507279         2009-07-14
# 5521  AG-910-P19  SRR6507279        0.000000  SRR6507279         2009-07-14
# 5522  AG-910-P20  SRR6507279        0.000000  SRR6507279         2009-07-14
#
#      mg_cruise_id  mg_BioSample mg_Depth mg_downloaded
# 0         BATS173  SAMN07137079       1m           yes
# 1         BATS173  SAMN07137079       1m           yes
# 2         BATS173  SAMN07137079       1m           yes
# 3         BATS173  SAMN07137079       1m           yes
# 4         BATS173  SAMN07137079       1m           yes
# ...           ...           ...      ...           ...
# 5518      BATS248  SAMN08390924      10m           yes
# 5519      BATS248  SAMN08390924      10m           yes
# 5520      BATS248  SAMN08390924      10m           yes
# 5521      BATS248  SAMN08390924      10m           yes
# 5522      BATS248  SAMN08390924      10m           yes
#
# [5523 rows x 9 columns]

# %% [markdown]
# OK, let's plot!  First, let's look at how well these SAGs represented these metagenomes by looking at the distribution of unmapped reads:

# %%
plot_df = bdf[bdf['Genome'] == 'unmapped']

sns.histplot(100-plot_df['perc_rel_abund'])

plt.xlabel('Percent metagenomic relative abundance')
plt.ylabel('Metagenomic Sample Count')
plt.title('Representation of all SAGs on plate AG-910')
plt.show()

# %% [markdown]
# Looks like variable "success" recuiting metagenomic reads to SAGs on this plate.

# %%
# Check how many samples we have at each depth:
Counter(mg_metadata['mg_Depth'])
# Out:
# Counter({'1m': 15, '10m': 6})

# %% [markdown]
# How does relative representation vary by collection date?
#
# First we need to format collection date in our dataframe so that we can plot it.  It is currently in this format:

# %%
bdf['mg_Collection_date']
# Out:
# 0       2003-02-21
# 1       2003-02-21
# 2       2003-02-21
# 3       2003-02-21
# 4       2003-02-21
#            ...
# 5518    2009-07-14
# 5519    2009-07-14
# 5520    2009-07-14
# 5521    2009-07-14
# 5522    2009-07-14
# Name: mg_Collection_date, Length: 5523, dtype: object

# %%
# split date by year, month, day
bdf[['mg_year','mg_month','mg_day']] = bdf['mg_Collection_date'].str.split("-", expand = True)

# making month and day columns numeric (I want to keep year categorical, as there are only 3 different years examined)
bdf[['mg_month','mg_day']] = bdf[['mg_month','mg_day']].apply(pd.to_numeric)

# finally, converting the original date column to date format (not actually necessary, just showing how to do it)
bdf['mg_Collection_date'] = pd.to_datetime(bdf['mg_Collection_date'])

bdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5523 entries, 0 to 5522
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Genome              5523 non-null   object
#  1   metagenome          5523 non-null   object
#  2   perc_rel_abund      5523 non-null   float64
#  3   mg_Run              5523 non-null   object
#  4   mg_Collection_date  5523 non-null   datetime64[ns]
#  5   mg_cruise_id        5523 non-null   object
#  6   mg_BioSample        5523 non-null   object
#  7   mg_Depth            5523 non-null   object
#  8   mg_downloaded       5523 non-null   object
#  9   mg_year             5523 non-null   object
#  10  mg_month            5523 non-null   int64
#  11  mg_day              5523 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 517.9+ KB

# %% [markdown]
# Plotting abundance by date:

# %%
# quick and dirty:

plot_df = bdf[(bdf['Genome'] == 'unmapped') & (bdf['mg_year'] != '2009')]

sns.lineplot(x = 'mg_Collection_date', y = 100 - plot_df['perc_rel_abund'], data = plot_df)
# Out:
# <Axes: xlabel='mg_Collection_date', ylabel='perc_rel_abund'>

# %%
# A little nicer looking

fig, ax = plt.subplots(figsize=(8,5))

plot_df = bdf[(bdf['Genome'] == 'unmapped') & (bdf['mg_year'] != '2009')]

sns.lineplot(x = 'mg_Collection_date', y = 100 - plot_df['perc_rel_abund'], data = plot_df, ax = ax)

ax.set(xlabel="Date",
       ylabel="Relative metagenomic abundance (%)",
       title="AG-910 metagenomic representation")

# Define the date format
date_form = DateFormatter("%m-%y")
ax.xaxis.set_major_formatter(date_form)

# %% [markdown]
# Overlay relative abundance by Month:

# %%
plot_df = bdf[(bdf['Genome'] == 'unmapped')]

fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x = 'mg_month', 
             y = 100 - plot_df['perc_rel_abund'], 
             hue = 'mg_year',
             style = 'mg_year',
             data = plot_df,
            markers = True, 
            ax = ax)

ax.set(xlabel="Month",
       ylabel="Relative metagenomic abundance (%)",
       title="AG-910 metagenomic representation")
plt.show()

# %% [markdown]
# Was there a difference in sampling depth?  When were metagenomes sampled from 10m?
#
# Let's check up on sampling depth by highlighting those metagenomic timepoints that were sampled at 10m.

# %%
plot_df = bdf[(bdf['Genome'] == 'unmapped')]

fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x = 'mg_month', 
             y = 100 - plot_df['perc_rel_abund'], 
             hue = 'mg_year',
             style = 'mg_year',
             data = plot_df,
            markers = True,
            ax = ax)

# want to highlight samples that came from 10m depth
plot_df2 = bdf[(bdf['Genome'] == 'unmapped') & (bdf['mg_Depth'] == '10m')]

sns.scatterplot(x = 'mg_month', 
             y = 100 - plot_df['perc_rel_abund'], 
             s = 200,
            color = 'gray',
             alpha = 0.5,
             data = plot_df2,
            markers = True,
               ax = ax)

ax.set(xlabel="Date",
       ylabel="Relative metagenomic abundance (%)",
       title="AG-910 metagenomic representation")

plt.show()

# %%
# want to only plot samples that came from 1m depth
plot_df2 = bdf[(bdf['Genome'] == 'unmapped') & (bdf['mg_Depth'] == '1m')]

fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x = 'mg_month', 
             y = 100 - plot_df2['perc_rel_abund'], 
             hue = 'mg_year',
             style = 'mg_year',
             data = plot_df2,
            markers = True, 
            ax = ax)

ax.set(xlabel="Month",
       ylabel="Relative metagenomic abundance (%)",
       title="AG-910 metagenomic representation")
plt.show()

# %%
# Boxplot of metagenomic read recruitment by depth for all SAGs on plate

plot_df = bdf[bdf['Genome'] == 'unmapped']

sns.boxplot(x = plot_df['mg_Depth'], y = 100 - plot_df['perc_rel_abund'])

plt.ylabel('Percent metagenomic relative abundance')
plt.xlabel('Metagenome Sampling Depth')
plt.title('Metagenomic Recruitment to Plate AG-910')

plt.show()

# %% [markdown]
# One thing to note about running coverM on all SAGs at the same time is that you get *an estimate of community abundance*.  Metagenomic reads are **competitively recruited**. That is to say, if you have two very similar genomes and a read that matches both, it will only be counted once. As such, running CoverM on all cells as inputs in the same run will not return an 'individual's' abundance.
#
# If we sum the percent abundances per metagenomic run in the output table we're working with, you can see what I mean:

# %%
bdf.groupby(['mg_Run'])['perc_rel_abund'].sum()
# Out:
# mg_Run
# SRR5720233     99.999999
# SRR5720235    100.000002
# SRR5720238    100.000001
# SRR5720251    100.000000
# SRR5720256     99.999994
# SRR5720257    100.000001
# SRR5720260    100.000003
# SRR5720262    100.000000
# SRR5720276    100.000004
# SRR5720278    100.000004
# SRR5720283    100.000001
# SRR5720286    100.000007
# SRR5720307    100.000002
# SRR5720321     99.999995
# SRR5720322     99.999999
# SRR5720327     99.999995
# SRR5720332    100.000003
# SRR5720337    100.000010
# SRR5720338     99.999994
# SRR5720342     99.999996
# SRR6507279     99.999994
# Name: perc_rel_abund, dtype: float64

# %% [markdown]
# So looking at individual SAG abundances with these outputs is not going to be too informative if there are related genomes on the plate.  A more informative look would be to examine relative abundances of groups based on taxonomy.  Classification information is included in the assembly statics file (we assigned the path to this file as sag_metadata above)

# %%
sag = pd.read_csv(sag_metadata, sep = ",")
sag.columns
# Out:
# Index(['well', 'well_type', 'diameter', 'wga_cp', 'raw_read_count',
#        'final_assembly_length', 'contig_count', 'max_contig_length',
#        'gc_content', 'coding_density', 'rRNA', 'tRNA', 'CDS',
#        'percent_CDS_annotated', 'average_CDS_length',
#        'checkm1_est_genome_completeness', 'translation_table',
#        'multicopy_marker_genes', 'classification_via_GTDBTk',
#        '1_SSU_classification', '2_SSU_classification', '3_SSU_classification',
#        '531/40_488', '572/27_488', '692/40_488', 'trigger_pulse_width',
#        'side_scatter', 'forward_scatter', 'probe', 'notes'],
#       dtype='object')

# %% [markdown]
# We will only focus on 'classification_via_GTDBTk' for this exercise so will select this column and then split into the different taxonomic levels

# %%
sag_taxonomy = sag[['well', 'classification_via_GTDBTk']]

sag_taxonomy[['domain','phyla','class','order','family','genus','species']] = sag_taxonomy['classification_via_GTDBTk'].str.split(';', expand = True)
sag_taxonomy
# Out:
# /tmp/ipykernel_1430597/3510788819.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sag_taxonomy[['domain','phyla','class','order','family','genus','species']] = sag_taxonomy['classification_via_GTDBTk'].str.split(';', expand = True)
# /tmp/ipykernel_1430597/3510788819.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sag_taxonomy[['domain','phyla','class','order','family','genus','species']] = sag_taxonomy['classification_via_GTDBTk'].str.split(';', expand = True)
# /tmp/ipykernel_1430597/3510788819.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sag_taxonomy[['domain','phyla','class','order','family','genus','species']] = sag_taxonomy['classification_via_GTDBTk'].str.split(';', expand = True)
# /tmp/ipykernel_1430597/3510788819.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sag_taxonomy[['domain','phyla','class','order','family','genus','species']] = sag_taxonomy['classification_via_GTDBTk'].str.split(';', expand = True)
# /tmp/ipykernel_1430597/3510788819.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sag_taxonomy[['domain','phyla','class','order','family','genus','species']] = sag_taxonomy['classification_via_GTDBTk'].str.split(';', expand = True)
# /tmp/ipykernel_1430597/3510788819.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sag_taxonomy[['domain','phyla','class','order','family','genus','species']] = sag_taxonomy['classification_via_GTDBTk'].str.split(';', expand = True)
# /tmp/ipykernel_1430597/3510788819.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sag_taxonomy[['domain','phyla','class','order','family','genus','species']] = sag_taxonomy['classification_via_GTDBTk'].str.split(';', expand = True)
#            well                          classification_via_GTDBTk  \
# 0    AG-910-A01                                                  0
# 1    AG-910-A02  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...
# 2    AG-910-A03                                                  0
# 3    AG-910-A04  d__Bacteria;p__Actinobacteriota;c__Acidimicrob...
# 4    AG-910-A05                                                  0
# ..          ...                                                ...
# 379  AG-910-P20                                                  0
# 380  AG-910-P21                                                NaN
# 381  AG-910-P22                                                NaN
# 382  AG-910-P23                                                NaN
# 383  AG-910-P24                                                NaN
#
#           domain                phyla                   class  \
# 0              0                 None                    None
# 1    d__Bacteria    p__Proteobacteria  c__Gammaproteobacteria
# 2              0                 None                    None
# 3    d__Bacteria  p__Actinobacteriota       c__Acidimicrobiia
# 4              0                 None                    None
# ..           ...                  ...                     ...
# 379            0                 None                    None
# 380          NaN                  NaN                     NaN
# 381          NaN                  NaN                     NaN
# 382          NaN                  NaN                     NaN
# 383          NaN                  NaN                     NaN
#
#                   order               family            genus  \
# 0                  None                 None             None
# 1              o__SAR86           f__TMED112       g__TMED112
# 2                  None                 None             None
# 3    o__Actinomarinales  f__Actinomarinaceae  g__Actinomarina
# 4                  None                 None             None
# ..                  ...                  ...              ...
# 379                None                 None             None
# 380                 NaN                  NaN              NaN
# 381                 NaN                  NaN              NaN
# 382                 NaN                  NaN              NaN
# 383                 NaN                  NaN              NaN
#
#                          species
# 0                           None
# 1         s__TMED112 sp003280455
# 2                           None
# 3    s__Actinomarina sp902615855
# 4                           None
# ..                           ...
# 379                         None
# 380                          NaN
# 381                          NaN
# 382                          NaN
# 383                          NaN
#
# [384 rows x 9 columns]

# %%
bdf = bdf.merge(sag_taxonomy[['well','domain','phyla','class','order','family','genus','species']], 
          left_on = 'Genome', 
          right_on = 'well', 
          how = 'left')

# %%
bdf
# Out:
#           Genome  metagenome  perc_rel_abund      mg_Run mg_Collection_date  \
# 0       unmapped  SRR5720233       96.039550  SRR5720233         2003-02-21
# 1     AG-910-A01  SRR5720233        0.000000  SRR5720233         2003-02-21
# 2     AG-910-A02  SRR5720233        0.000000  SRR5720233         2003-02-21
# 3     AG-910-A03  SRR5720233        0.000000  SRR5720233         2003-02-21
# 4     AG-910-A04  SRR5720233        0.000000  SRR5720233         2003-02-21
# ...          ...         ...             ...         ...                ...
# 5518  AG-910-P09  SRR6507279        0.000000  SRR6507279         2009-07-14
# 5519  AG-910-P13  SRR6507279        0.089771  SRR6507279         2009-07-14
# 5520  AG-910-P17  SRR6507279        0.197070  SRR6507279         2009-07-14
# 5521  AG-910-P19  SRR6507279        0.000000  SRR6507279         2009-07-14
# 5522  AG-910-P20  SRR6507279        0.000000  SRR6507279         2009-07-14
#
#      mg_cruise_id  mg_BioSample mg_Depth mg_downloaded mg_year  mg_month  \
# 0         BATS173  SAMN07137079       1m           yes    2003         2
# 1         BATS173  SAMN07137079       1m           yes    2003         2
# 2         BATS173  SAMN07137079       1m           yes    2003         2
# 3         BATS173  SAMN07137079       1m           yes    2003         2
# 4         BATS173  SAMN07137079       1m           yes    2003         2
# ...           ...           ...      ...           ...     ...       ...
# 5518      BATS248  SAMN08390924      10m           yes    2009         7
# 5519      BATS248  SAMN08390924      10m           yes    2009         7
# 5520      BATS248  SAMN08390924      10m           yes    2009         7
# 5521      BATS248  SAMN08390924      10m           yes    2009         7
# 5522      BATS248  SAMN08390924      10m           yes    2009         7
#
#       mg_day        well       domain                phyla  \
# 0         21         NaN          NaN                  NaN
# 1         21  AG-910-A01            0                 None
# 2         21  AG-910-A02  d__Bacteria    p__Proteobacteria
# 3         21  AG-910-A03            0                 None
# 4         21  AG-910-A04  d__Bacteria  p__Actinobacteriota
# ...      ...         ...          ...                  ...
# 5518      14  AG-910-P09            0                 None
# 5519      14  AG-910-P13  d__Bacteria    p__Proteobacteria
# 5520      14  AG-910-P17  d__Bacteria    p__Proteobacteria
# 5521      14  AG-910-P19  d__Bacteria    p__Proteobacteria
# 5522      14  AG-910-P20            0                 None
#
#                        class                  order                family  \
# 0                        NaN                    NaN                   NaN
# 1                       None                   None                  None
# 2     c__Gammaproteobacteria               o__SAR86            f__TMED112
# 3                       None                   None                  None
# 4          c__Acidimicrobiia     o__Actinomarinales   f__Actinomarinaceae
# ...                      ...                    ...                   ...
# 5518                    None                   None                  None
# 5519  c__Alphaproteobacteria  o__Puniceispirillales         f__AAA536-G10
# 5520  c__Alphaproteobacteria    o__Pelagibacterales  f__Pelagibacteraceae
# 5521  c__Alphaproteobacteria    o__Pelagibacterales  f__Pelagibacteraceae
# 5522                    None                   None                  None
#
#                   genus                      species
# 0                   NaN                          NaN
# 1                  None                         None
# 2            g__TMED112       s__TMED112 sp003280455
# 3                  None                         None
# 4       g__Actinomarina  s__Actinomarina sp902615855
# ...                 ...                          ...
# 5518               None                         None
# 5519          g__TMED54                          s__
# 5520    g__Pelagibacter  s__Pelagibacter sp902594705
# 5521  g__Pelagibacter_A                          s__
# 5522               None                         None
#
# [5523 rows x 20 columns]

# %%
order_rel_abund = bdf.groupby(['order','mg_Run','mg_Collection_date','mg_year','mg_month','mg_day'], as_index = False)['perc_rel_abund'].sum()

# %%
order_rel_abund
# Out:
#                   order      mg_Run mg_Collection_date mg_year  mg_month  \
# 0    o__Actinomarinales  SRR5720233         2003-02-21    2003         2
# 1    o__Actinomarinales  SRR5720235         2003-07-15    2003         7
# 2    o__Actinomarinales  SRR5720238         2003-03-22    2003         3
# 3    o__Actinomarinales  SRR5720251         2004-09-14    2004         9
# 4    o__Actinomarinales  SRR5720256         2004-04-21    2004         4
# ..                  ...         ...                ...     ...       ...
# 247          o__TMED127  SRR5720332         2003-10-07    2003        10
# 248          o__TMED127  SRR5720337         2004-03-23    2004         3
# 249          o__TMED127  SRR5720338         2004-01-27    2004         1
# 250          o__TMED127  SRR5720342         2004-12-08    2004        12
# 251          o__TMED127  SRR6507279         2009-07-14    2009         7
#
#      mg_day  perc_rel_abund
# 0        21        0.041237
# 1        15        0.076325
# 2        22        0.040853
# 3        14        0.458722
# 4        21        0.150907
# ..      ...             ...
# 247       7        0.000000
# 248      23        0.000000
# 249      27        0.000000
# 250       8        0.000000
# 251      14        0.079425
#
# [252 rows x 7 columns]

# %% [markdown]
# Now let's plot:

# %%
fig, ax = plt.subplots(figsize=(8,5))

sns.lineplot(x = 'mg_Collection_date', 
             y = 'perc_rel_abund', 
             hue = 'order', 
             data = order_rel_abund[order_rel_abund['mg_year'] != '2009'],
            ax = ax)

ax.set(xlabel="Date",
       ylabel="Relative metagenomic abundance (%)",
       title="AG-910 metagenomic representation")

plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

plt.show()

# %% [markdown]
# These results can also be visualized as a heatmap:

# %%
to_plot = order_rel_abund.pivot(index = 'order',columns = 'mg_Run', values = 'perc_rel_abund')

#heatmap with default colors
sns.heatmap(to_plot)
# Out:
# <Axes: xlabel='mg_Run', ylabel='order'>

# %% [raw]
# I have issues vizualing zeros as black (or dak colors in general)

# %%
to_plot = order_rel_abund.pivot(index = 'order',columns = 'mg_Collection_date', values = 'perc_rel_abund')

sns.heatmap(to_plot, cmap="BuPu")
# Out:
# <Axes: xlabel='mg_Collection_date', ylabel='order'>

# %% [markdown]
# ### Possible Next Steps:
#
# #### Use different metagenomes
# * Examine metagenomic representation of AG-910 at different locations and over time (e.g. HOT surface samples)
# * Examine represenation of AG-910 in deeper samples
#
# #### Use different genome inputs
# * Run the same SAGs and metagenomes again, but add the ```--dereplicate``` flag in the CoverM command
# * Run CoverM on individuals, rather than on a collection.
# * Create heatmap of individual abundances
#     * Do SAGs from the same genus exhibit similar patterns of relative abundance within these metagenomes?
